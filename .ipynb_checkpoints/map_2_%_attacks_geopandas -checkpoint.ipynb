# %%
import geopandas as gpd
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
import os

# %%
# get the path in order to get the needed files
path = os.getcwd()

# %% [markdown]
# ## First, I create a dataframe about all the countries

# %%
# read the geopandas dataset which contains the geometry(polygons that represent the shape of countries) for every country.
shape = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))


# read the csv file which contains all the reported shark attacks that occured globaly
df = pd.read_csv(path+'\\files_for_plots\\attacks2.csv')

# %%
# df is a new dataframe with countries and the number of shark attacks for each country
df = pd.DataFrame(df['Country'].value_counts())

# I made some changes to the df form in order to merge it with shape dataset
df.reset_index(inplace=True)
df.rename(columns={'index':'name','Country':'Counts'},inplace=True)
df = df.replace('Usa','United States of America')

# %%
# merging the two dataframes
shape=shape.merge(df,'left')

# %%
# create a new column with % values for each country
shape['% Counts'] = (shape['Counts']*100)/shape['pop_est']

# %%
#
#
#
shape['%% Counts'] = (shape['Counts']*1000000)/shape['pop_est']

# %% [markdown]
# ## Then, I create a dataframe for the states of USA

# %%
# As previous, these are the two dataframes with the geometry and the sark attacks, respectively.

states = gpd.read_file(path+'\\files_for_plots\\cb_2018_us_state_500k\\cb_2018_us_state_500k.shp')
df2 = pd.read_csv(path+'\\files_for_plots\\attacks2.csv')

# %%
# In this case, I keep only the rows with shark attacks that took place in USA.
df2 = df2[df2['Country']=='Usa']

df2 = pd.DataFrame(df2['Area'].value_counts())
df2.reset_index(inplace=True)
df2.rename(columns={'index':'name','Area':'Counts'},inplace=True)
df2.rename(columns={'name':'NAME'},inplace=True)
df2.replace({'CUBA':'Cuba'},inplace=True)
#states=states.merge(df2,'left')

# %% [markdown]
# ## I find the percentage of attacks according to the population of each country/state.

# %%
# I had to use an extra dataframe which contains the population of each state because the shp file doesn't include this inforamtion
us_pop = pd.read_csv(path+'\\files_for_plots\\us_states_pop.csv')

# %%
# I changed the column name to merge us_pop with df2
us_pop.rename(columns={'POPESTIMATE2019':'population'},inplace=True)

# %%
# drop columnσ that are not needed
us_pop.drop(['lat','long'],axis=1,inplace=True)

# %%
# rename the column to merge with states
us_pop.rename(columns={'STATE':'NAME'},inplace=True)

# %%
# merge df2 with us_pop
df2=df2.merge(us_pop,'left')

# %%
# merge states with df2
states=states.merge(df2,'left')

# %%
# create a new column with % values for each state
states['% Counts'] = (states['Counts']*100/states['population']) #

# %%
#
#
#
#
states['%% Counts'] = (states['Counts']*1000000/states['population']) #

# %%
# drop column that are not needed
shape=shape.drop(['continent','iso_a3','gdp_md_est'],axis=1)

# %%
states=states.drop(['STATEFP','STATENS','AFFGEOID','STUSPS','LSAD','ALAND','AWATER'],axis=1)

# %%
states=states.drop('GEOID',axis=1)

# %%
# rename columns to have cleaner data
states.rename(columns={'NAME':'name','Area':'Counts','pop_est':'population'},inplace=True)

# %%
# change the columns order to organiuze them better
states = states[['population','name','geometry','Counts','% Counts','%% Counts']]

# %%
# editing the dataframe in order to merge it with 
states.rename(index={i:i+177 for i in range(len(states))}, inplace=True)

# %%
states.to_crs(crs='NAD83',inplace=True)

# %%
shape.to_crs(crs='NAD83',inplace=True)

# %%
# merge shape and states so I can use them as one dataframe for the plot
whole = pd.concat((shape,states))

# %% [markdown]
# ## Finally, I use the information of the two dataframes to create the following map.

# %%
# the kind of the plot (boundary : shows country/state borders)
ax = whole.boundary.plot(edgecolor='black', linewidth=0.2, figsize=(12,10))

# the data that are used in the plot
whole.plot(ax=ax, 
           column='% Counts', 
           legend=True, 
           cmap='Reds', 
           legend_kwds={'shrink':0.5,'orientation':'horizontal','format':'%.3f%%'}, 
           missing_kwds={'color':'lightgrey'})

# to hide the lines and axis around the plot
ax.get_xaxis().set_visible(False)
ax.get_yaxis().set_visible(False)

for edge in ['right','left','top','bottom']:
    ax.spines[edge].set_visible(False)
    
# setting title
ax.set_title('Shark attacks in the world (% of each country/state population)', size=15, weight='bold')

#plt.savefig('attacks%%.png')
# Out:
# Text(0.5, 1.0, 'Shark attacks in the world (% of each country/state population)')

# %%
# the kind of the plot (boundary : shows country/state borders)
ax = whole.boundary.plot(edgecolor='black', linewidth=0.2, figsize=(12,10))

# the data that are used in the plot
whole.plot(ax=ax, 
           column='%% Counts', 
           legend=True, 
           cmap='Reds', 
           legend_kwds={'shrink':0.5,'orientation':'horizontal','format':'%.0f/m'}, 
           missing_kwds={'color':'lightgrey'})

# to hide the lines and axis around the plot
ax.get_xaxis().set_visible(False)
ax.get_yaxis().set_visible(False)

for edge in ['right','left','top','bottom']:
    ax.spines[edge].set_visible(False)
    
# setting title
ax.set_title('Shark attacks in the world / million people', size=15, weight='bold')

#plt.savefig('attacks%%.png')
# Out:
# Text(0.5, 1.0, 'Shark attacks in the world / million people')

# %%
states
# Out:
#      population                                          name  \
# 177   2976149.0                                   Mississippi
# 178  10488084.0                                North Carolina
# 179         NaN                                      Oklahoma
# 180   8535519.0                                      Virginia
# 181         NaN                                 West Virginia
# 182   4648794.0                                     Louisiana
# 183         NaN                                      Michigan
# 184   6892503.0                                 Massachusetts
# 185         NaN                                         Idaho
# 186  21477737.0                                       Florida
# 187         NaN                                      Nebraska
# 188   7614893.0                                    Washington
# 189   2096829.0                                    New Mexico
# 190         NaN                                   Puerto Rico
# 191         NaN                                  South Dakota
# 192  28995881.0                                         Texas
# 193  39512223.0                                    California
# 194   4903185.0                                       Alabama
# 195  10617423.0                                       Georgia
# 196  12801989.0                                  Pennsylvania
# 197   6137428.0                                      Missouri
# 198         NaN                                      Colorado
# 199         NaN                                          Utah
# 200         NaN                                     Tennessee
# 201         NaN                                       Wyoming
# 202  19453561.0                                      New York
# 203         NaN                                        Kansas
# 204    731545.0                                        Alaska
# 205         NaN                                        Nevada
# 206  12671821.0                                      Illinois
# 207         NaN                                       Vermont
# 208         NaN                                       Montana
# 209         NaN                                          Iowa
# 210   5148714.0                                South Carolina
# 211         NaN                                 New Hampshire
# 212         NaN                                       Arizona
# 213         NaN                          District of Columbia
# 214         NaN                                American Samoa
# 215         NaN                  United States Virgin Islands
# 216   8882190.0                                    New Jersey
# 217   6045680.0                                      Maryland
# 218   1344212.0                                         Maine
# 219   1415872.0                                        Hawaii
# 220    973764.0                                      Delaware
# 221         NaN                                          Guam
# 222         NaN  Commonwealth of the Northern Mariana Islands
# 223   1059361.0                                  Rhode Island
# 224   4467673.0                                      Kentucky
# 225         NaN                                          Ohio
# 226         NaN                                     Wisconsin
# 227   4217737.0                                        Oregon
# 228         NaN                                  North Dakota
# 229         NaN                                      Arkansas
# 230         NaN                                       Indiana
# 231         NaN                                     Minnesota
# 232   3565287.0                                   Connecticut
#
#                                               geometry  Counts  % Counts  \
# 177  MULTIPOLYGON (((-88.50297 30.21523, -88.49176 ...     6.0  0.000202
# 178  MULTIPOLYGON (((-75.72681 35.93584, -75.71827 ...   111.0  0.001058
# 179  POLYGON ((-103.00257 36.52659, -103.00219 36.6...     NaN       NaN
# 180  MULTIPOLYGON (((-75.74241 37.80835, -75.74151 ...    19.0  0.000223
# 181  POLYGON ((-82.64320 38.16909, -82.64300 38.169...     NaN       NaN
# 182  MULTIPOLYGON (((-88.86770 29.86155, -88.86566 ...    13.0  0.000280
# 183  MULTIPOLYGON (((-83.19159 42.03537, -83.18993 ...     NaN       NaN
# 184  MULTIPOLYGON (((-70.23405 41.28565, -70.22361 ...    16.0  0.000232
# 185  POLYGON ((-117.24267 44.39655, -117.23484 44.3...     NaN       NaN
# 186  MULTIPOLYGON (((-80.17628 25.52505, -80.17395 ...  1076.0  0.005010
# 187  POLYGON ((-104.05342 41.17054, -104.05324 41.1...     NaN       NaN
# 188  MULTIPOLYGON (((-122.57039 48.53785, -122.5686...     2.0  0.000026
# 189  POLYGON ((-109.05017 31.48000, -109.04984 31.4...     1.0  0.000048
# 190  MULTIPOLYGON (((-65.23805 18.32167, -65.23467 ...    16.0       NaN
# 191  POLYGON ((-104.05788 44.99761, -104.05078 44.9...     NaN       NaN
# 192  MULTIPOLYGON (((-94.71830 29.72885, -94.71721 ...    75.0  0.000259
# 193  MULTIPOLYGON (((-118.60442 33.47855, -118.5987...   294.0  0.000744
# 194  MULTIPOLYGON (((-88.05338 30.50699, -88.05109 ...    15.0  0.000306
# 195  MULTIPOLYGON (((-81.27939 31.30792, -81.27716 ...    15.0  0.000141
# 196  POLYGON ((-80.51989 40.90666, -80.51909 40.921...     1.0  0.000008
# 197  POLYGON ((-95.77355 40.57820, -95.76853 40.583...     1.0  0.000016
# 198  POLYGON ((-109.06025 38.59933, -109.05954 38.7...     NaN       NaN
# 199  POLYGON ((-114.05296 37.59278, -114.05247 37.6...     NaN       NaN
# 200  POLYGON ((-90.31030 35.00429, -90.30988 35.009...     NaN       NaN
# 201  POLYGON ((-111.05456 45.00095, -111.04507 45.0...     NaN       NaN
# 202  MULTIPOLYGON (((-72.03683 41.24984, -72.03496 ...    35.0  0.000180
# 203  POLYGON ((-102.05174 40.00308, -101.91670 40.0...     NaN       NaN
# 204  MULTIPOLYGON (((179.48246 51.98283, 179.48656 ...     1.0  0.000137
# 205  POLYGON ((-120.00574 39.22866, -120.00559 39.2...     NaN       NaN
# 206  POLYGON ((-91.51297 40.18106, -91.51107 40.188...     1.0  0.000008
# 207  POLYGON ((-73.43774 44.04501, -73.43199 44.063...     NaN       NaN
# 208  POLYGON ((-116.04914 48.50205, -116.04913 48.5...     NaN       NaN
# 209  POLYGON ((-96.63970 42.73707, -96.63589 42.741...     NaN       NaN
# 210  MULTIPOLYGON (((-79.50795 33.02008, -79.50713 ...   162.0  0.003146
# 211  MULTIPOLYGON (((-70.61702 42.97718, -70.61529 ...     NaN       NaN
# 212  POLYGON ((-114.81629 32.50804, -114.81432 32.5...     NaN       NaN
# 213  POLYGON ((-77.11976 38.93434, -77.11253 38.940...     NaN       NaN
# 214  MULTIPOLYGON (((-168.14582 -14.54791, -168.145...     NaN       NaN
# 215  MULTIPOLYGON (((-64.62799 17.78933, -64.62717 ...     NaN       NaN
# 216  POLYGON ((-75.55910 39.62906, -75.55945 39.629...    55.0  0.000619
# 217  MULTIPOLYGON (((-76.05015 37.98691, -76.04998 ...     7.0  0.000116
# 218  MULTIPOLYGON (((-67.35580 44.64226, -67.35437 ...     1.0  0.000074
# 219  MULTIPOLYGON (((-156.06076 19.73055, -156.0566...   312.0  0.022036
# 220  MULTIPOLYGON (((-75.56555 39.51485, -75.56174 ...     7.0  0.000719
# 221  MULTIPOLYGON (((144.64538 13.23627, 144.64716 ...     2.0       NaN
# 222  MULTIPOLYGON (((146.05103 16.00674, 146.05167 ...     NaN       NaN
# 223  MULTIPOLYGON (((-71.28802 41.64558, -71.28647 ...     9.0  0.000850
# 224  MULTIPOLYGON (((-89.40565 36.52817, -89.39869 ...     1.0  0.000022
# 225  MULTIPOLYGON (((-82.73571 41.60336, -82.73392 ...     NaN       NaN
# 226  MULTIPOLYGON (((-86.95617 45.35549, -86.95463 ...     NaN       NaN
# 227  MULTIPOLYGON (((-123.59892 46.25145, -123.5984...    30.0  0.000711
# 228  POLYGON ((-104.04868 48.86378, -104.04865 48.8...     NaN       NaN
# 229  POLYGON ((-94.61783 36.49941, -94.61765 36.499...     NaN       NaN
# 230  POLYGON ((-88.09776 37.90403, -88.09448 37.905...     NaN       NaN
# 231  MULTIPOLYGON (((-89.59206 47.96668, -89.59147 ...     NaN       NaN
# 232  MULTIPOLYGON (((-72.76143 41.24233, -72.75973 ...     6.0  0.000168
#
#       %% Counts
# 177    2.016028
# 178   10.583439
# 179         NaN
# 180    2.225992
# 181         NaN
# 182    2.796424
# 183         NaN
# 184    2.321363
# 185         NaN
# 186   50.098388
# 187         NaN
# 188    0.262643
# 189    0.476911
# 190         NaN
# 191         NaN
# 192    2.586574
# 193    7.440735
# 194    3.059236
# 195    1.412772
# 196    0.078113
# 197    0.162935
# 198         NaN
# 199         NaN
# 200         NaN
# 201         NaN
# 202    1.799156
# 203         NaN
# 204    1.366970
# 205         NaN
# 206    0.078915
# 207         NaN
# 208         NaN
# 209         NaN
# 210   31.464168
# 211         NaN
# 212         NaN
# 213         NaN
# 214         NaN
# 215         NaN
# 216    6.192167
# 217    1.157852
# 218    0.743930
# 219  220.358902
# 220    7.188600
# 221         NaN
# 222         NaN
# 223    8.495687
# 224    0.223830
# 225         NaN
# 226         NaN
# 227    7.112819
# 228         NaN
# 229         NaN
# 230         NaN
# 231         NaN
# 232    1.682894
